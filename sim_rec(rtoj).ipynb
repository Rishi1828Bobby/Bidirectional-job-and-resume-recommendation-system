# %%
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
# %matplotlib inline

import re
import datetime
from datetime import date
from time import strptime

from sklearn.metrics.pairwise import cosine_similarity

# %%
resume = pd.read_csv('con_resume_new.csv')
resume
# Out:
#        index                                       Resume_title       City  \
# 0          0                                     java developer      Tirur
# 1          1                                 software developer  Bengaluru
# 2          2                                     java developer       Pune
# 3          3  seeking innovative and challenging career assi...       Pune
# 4          4                                     java developer       Pune
# ...      ...                                                ...        ...
# 14793  14793            back office operations & hr coordinator    Calicut
# 14794  14794                                         accountant       NONE
# 14795  14795                               administrative works   Durgapur
# 14796  14796                                   assistant manger       NONE
# 14797  14797                                 commercial officer     Howrah
#
# ...

# %%
job = pd.read_csv('con_job_new.csv')

# %%
def jobs_recommender(r) :
    
    #job features need to be matched with resume
    # job_m = related_jobs[['j_id','vec_1','vec_2','vec_3','vec_4','vec_5','vec_6','vec_7','vec_8','vec_9','vec_10','vec_11','vec_12',
    #           'vec_13','vec_14','vec_15','vec_16','vec_17','vec_18','vec_19','vec_20']]

    #Store the results in this DF
    matched_jobs = pd.DataFrame(columns = ["id","company","job_title","jobdescription","experience_range","is_grad","similarity"] )
    
    r= r.to_numpy()
    r= r.reshape(1, -1)
    # job_m.to_numpy()
    #Go through ALL the related jobs
    for i,j in enumerate(job_m) :
        # print(f'jd is {jd}')        
        #Find the similarity of the jobs with resume
        jobs = j
        jd=i
        # print(jd)
        # jobs = jobs.to_numpy()
        jobs = jobs.reshape(1, -1)
        #print(f'job is {jobs}')
        #print(f'r is {r}')
        #print(f'job is {job}')
        similarity = cosine_similarity(r,jobs)
        # print(123)
        #print(f'similarity is {similarity}')
        matched_jobs.loc[len(matched_jobs)] = [jd,
                                               related_jobs[jd][1],
                                               related_jobs[jd][6],
                                               related_jobs[jd][5],
                                               related_jobs[jd][10],
                                               related_jobs[jd][12],
                                               similarity[0][0]]
        
    return matched_jobs.sort_values(by=['similarity'],ascending=False)[1:].iloc[:, :-1]

# %%
x=14
columns = ['vec_' + str(i) for i in range(1, 21)]

# Extract columns from row 13 (label 12)
resume_vector=resume.loc[x, columns]
resume_title=resume.loc[x,'Resume_title']
resume_vector=resume.values
resume_title
# Out:
# 'java developer'

# %%
# vectors=pd.read_csv('modified_resume_vectors.csv')

# %%
r_df = resume[['index','experience_range','is_grad','is_postgrad','is_doc','vec_1','vec_2','vec_3','vec_4','vec_5','vec_6','vec_7','vec_8','vec_9','vec_10','vec_11','vec_12',
              'vec_13','vec_14','vec_15','vec_16','vec_17','vec_18','vec_19','vec_20']]

# %%
r1= r_df.loc[1]
r1
# Out:
# index               1.000000
# experience_range    1.000000
# is_grad             1.000000
# is_postgrad         1.000000
# is_doc              0.000000
# vec_1              -2.499004
# vec_2               0.200497
# vec_3              -0.794383
# vec_4               0.931614
# vec_5              -2.418982
# vec_6              -3.106181
# vec_7               0.424919
# vec_8               1.302060
# vec_9              -2.168684
# vec_10              0.911881
# vec_11              1.298089
# vec_12             -1.820087
# vec_13              0.641809
# vec_14              1.595022
# vec_15              0.220402
# vec_16              2.217785
# vec_17              1.296798
# vec_18             -3.018250
# vec_19             -0.151164
# vec_20              0.136133
# Name: 1, dtype: float64

# %%
unique_title = job['jobtitle'].unique().tolist()
unique_title.sort()
from fuzzywuzzy import process, fuzz
title_score_sort = [(resume_title,) + i 
             for i in process.extract(resume_title, unique_title, scorer=fuzz.token_sort_ratio,limit=10)]
#Create a dataframe from the tuples
title_similarity_sort = pd.DataFrame(title_score_sort, columns=['title_original','title_checked','title_score_sort'])

titles_to_check = title_similarity_sort['title_checked'].str.lower().unique()
filtered_job = job[job['jobtitle'].str.lower().isin(titles_to_check)]

# %%
columns = ['vec_' + str(i) for i in range(1, 21)]
filtered_vectors = filtered_job.loc[:, columns]
# filtered_job[filtered_job['location']=="maharashtra"]

# %%
related_jobs = filtered_job
job_m = related_jobs[['j_id','experience_range','is_grad','is_postgrad','is_doc','vec_1','vec_2','vec_3','vec_4','vec_5','vec_6','vec_7','vec_8','vec_9','vec_10','vec_11','vec_12',
              'vec_13','vec_14','vec_15','vec_16','vec_17','vec_18','vec_19','vec_20']]
job_m=job_m.to_numpy()
job_m
related_jobs=related_jobs.to_numpy()
related_jobs[0][0]
# Out:
# 54

# %%
matched_jobs = jobs_recommender(r1)
matched_jobs = matched_jobs.head(20)

# %%
display(matched_jobs)
# Out:
#     id                                      company          job_title  \
# 4    4       Kinesis Management Consultant Pvt. Ltd    java developers
# 0    0       Kinesis Management Consultant Pvt. Ltd    java developers
# 1    1       Kinesis Management Consultant Pvt. Ltd    java developers
# 2    2       Kinesis Management Consultant Pvt. Ltd    java developers
# 3    3       Kinesis Management Consultant Pvt. Ltd    java developers
# 6    6                                 Confidential  sr.java developer
# 10  10           Technosoft Global Services Pvt Ltd     java developer
# 8    8                          executive-teams.com    java developers
# 9    9                          executive-teams.com    java developers
# 7    7                          executive-teams.com    java developers
# 13  13               TQuanta Technologies Pvt. Ltd.     java developer
# 11  11         Melstar Information Technologies Ltd     java developer
# ...
